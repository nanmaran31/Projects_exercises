# %%
#importing libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#reading txt file 

chels = pd.read_csv('/Users/z3433848/Desktop/DSI/Capstone/Chelsea.txt', sep='\t')

# %%
# sample of file 

chels.head(10)
# Out:
#            ID          Home_Team Home_Formation  Home_Score  Home_xG  \
# 0  2017-08-12            Chelsea          3-4-3           2      1.3
# 1  2017-08-20  Tottenham Hotspur        4-3-2-1           1      0.6
# 2  2017-08-27            Chelsea          3-4-3           2      1.1
# 3  2017-09-09     Leicester City          4-4-2           1      1.6
# 4  2017-09-17            Chelsea          3-4-3           0      0.8
# 5  2017-09-23         Stoke City          3-4-3           0      0.6
# 6  2017-09-30            Chelsea        3-5-1-1           0      0.3
# 7  2017-10-14     Crystal Palace          4-4-2           2      1.5
# 8  2017-10-21            Chelsea          3-4-3           4      1.5
# 9  2017-10-28        Bournemouth        3-4-1-2           0      0.7
#
#    Home_Yellow_Cards  Home_Red_Cards        Away_Team Away_Formation  \
# 0                  5               2          Burnley        4-4-1-1
# ...

# %%
# information of datatypes
chels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Columns: 157 entries, ID to MatchYear
# dtypes: float64(26), int64(122), object(9)
# memory usage: 213.5+ KB

# %%
#find range of columns 
chels.describe()
# Out:
#        Home_Score     Home_xG  Home_Yellow_Cards  Home_Red_Cards  Away_Score  \
# count   174.00000  174.000000         174.000000      174.000000  174.000000
# mean      1.54023    1.440805           1.557471        0.045977    1.218391
# std       1.34125    0.836937           1.344923        0.235961    1.220493
# min       0.00000    0.100000           0.000000        0.000000    0.000000
# 25%       0.25000    0.700000           0.000000        0.000000    0.000000
# 50%       1.00000    1.400000           1.000000        0.000000    1.000000
# 75%       2.00000    2.000000           2.000000        0.000000    2.000000
# max       7.00000    3.700000           6.000000        2.000000    5.000000
#
#           Away_xG  Away_Yellow_Cards  Away_Red_Cards         Gls         Ast  \
# count  174.000000         174.000000      174.000000  174.000000  174.000000
# mean     1.119540           1.637931        0.045977    1.672414    1.201149
# ...

# %%
#settingparameters 
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', None)
pd.options.display.max_seq_items = 2000

# %%
chels.head(2)
# Out:
#            ID          Home_Team Home_Formation  Home_Score  Home_xG  \
# 0  2017-08-12            Chelsea          3-4-3           2      1.3
# 1  2017-08-20  Tottenham Hotspur        4-3-2-1           1      0.6
#
#    Home_Yellow_Cards  Home_Red_Cards Away_Team Away_Formation  Away_Score  \
# 0                  5               2   Burnley        4-4-1-1           3
# 1                  4               0   Chelsea        3-5-1-1           2
#
#    Away_xG  Away_Yellow_Cards  Away_Red_Cards  Gls  Ast  PK  Sh  SoT  CrdY  \
# 0      0.8                  3               0    2    2   0  19    6     4
# 1      0.8                  3               0    2    1   0  10    2     3
#
#    CrdR  Touches  Press  Tkl  Int  Blocks  xG_Expected  npxG_Expected  \
# 0     2      668     97   13    9       8          1.3            1.3
# 1     0      449    144   31    5      23          0.8            0.8
#
#    xA_Expected  GCA_SCA  Cmp_Passes  Att_Passes  Cmp_percent_Passes  \
# ...

# %%
#list of columns 
chels.columns
# Out:
# Index(['ID', 'Home_Team', 'Home_Formation', 'Home_Score', 'Home_xG',
#        'Home_Yellow_Cards', 'Home_Red_Cards', 'Away_Team', 'Away_Formation',
#        'Away_Score', 'Away_xG', 'Away_Yellow_Cards', 'Away_Red_Cards', 'Gls',
#        'Ast', 'PK', 'Sh', 'SoT', 'CrdY', 'CrdR', 'Touches', 'Press', 'Tkl',
#        'Int', 'Blocks', 'xG_Expected', 'npxG_Expected', 'xA_Expected',
#        'GCA_SCA', 'Cmp_Passes', 'Att_Passes', 'Cmp_percent_Passes',
#        'Prog_Passes', 'Carries_Carries', 'Prog_Carries', 'Succ_Dribbles',
#        'Att_Dribbles', 'Cmp_Total', 'Att_Total', 'Cmp_percent_Total',
#        'TotDist_Total', 'PrgDist_Total', 'Cmp_Short', 'Att_Short',
#        'Cmp_percent_Short', 'Cmp_Medium', 'Att_Medium', 'Cmp_percent_Medium',
#        'Cmp_Long', 'Att_Long', 'Cmp_percent_Long', 'xA', 'KP', 'Final_Third',
#        'PPA', 'CrsPA', 'Prog', 'Att', 'Live_Pass_Types', 'Dead_Pass_Types',
#        'FK_Pass_Types', 'TB_Pass_Types', 'Press_Pass_Types', 'Sw_Pass_Types',
# ...

# %%
#filtering features 
#removing unwanted features from literature review 
df = chels[['xG','xGA','Poss','Formation','Touches', 'Press', 'Tkl', 'Int', 'Blocks', 'xG_Expected', 'npxG_Expected', 'xA_Expected','Att_Passes', 'Cmp_percent_Passes','Prog_Passes', 'Prog_Carries', 'Succ_Dribbles', 'Att_Dribbles', 'Cmp_percent_Total','TotDist_Total', 'PrgDist_Total', 'Att_Short', 'Cmp_percent_Short', 'Att_Medium', 'Cmp_percent_Medium', 'Att_Long', 'Cmp_percent_Long','PPA', 'CrsPA','Live_Pass_Types', 'Dead_Pass_Types','FK_Pass_Types', 'TB_Pass_Types', 'Press_Pass_Types', 'Sw_Pass_Types','Crs_Pass_Types', 'CK_Pass_Types', 'Int_Outcomes', 'Blocks_Outcomes', 'Tkl_Tackles','TklW_Tackles', 'Def.3rd_Tackles', 'Mid.3rd_Tackles', 'Att.3rd_Tackles', 'Att_Vs_Dribbles', 'Tkl_percent_Vs_Dribbles',    
       'Past_Vs_Dribbles', 'Press_Pressures', 'Succ_Pressures', 'Def.3rd_Pressures', 'Mid.3rd_Pressures',        'Att.3rd_Pressures', 'Sh_Blocks', 'ShSv_Blocks',        'Pass_Blocks', 'Tkl.Int', 'Clr', 'Err', 'Touches_Touches',
       'Def.Pen_Touches', 'Def.3rd_Touches', 'Mid.3rd_Touches','Att.3rd_Touches', 'Att.Pen_Touches','Succ_percent_Dribbles','PrgDist_Carries', 'Final_Third_Carries','CPA_Carries', 'Mis_Carries', 'Dis_Carries', 'Fls', 'Fld', 'Off', 'Crs', 'TklW', 'PKwon', 'PKcon','Won_percent_Aerial_Duels','Recov', 'Saves_Shot_Stopping', 
       'SoTA_Shot_Stopping','Att_Goal_Kicks' ,'Save_percent_Shot_Stopping', 'Stp_percent_Crosses','SoT', 'GCA_SCA','Prog', 'TotDist_Carries', 'PSxG_Shot_Stopping', 'Opp_Crosses', 'AvgDist_Sweeper', 'Player_NumOPA_Sweeper', 'Result']]

# %%
df.head(5)
# Out:
#     xG  xGA  Poss Formation  Touches  Press  Tkl  Int  Blocks  xG_Expected  \
# 0  1.3  0.8    63     3-4-3      668     97   13    9       8          1.3
# 1  0.8  0.6    32   3-5-1-1      449    144   31    5      23          0.8
# 2  1.1  0.6    56     3-4-3      738    146   14    5      10          1.1
# 3  1.5  1.6    58     3-4-3      693    130   26   17      16          1.5
# 4  0.8  1.4    52     3-4-3      700    189   18   16      18          0.8
#
#    npxG_Expected  xA_Expected  Att_Passes  Cmp_percent_Passes  Prog_Passes  \
# 0            1.3          1.1         569                81.9           36
# 1            0.8          0.7         309                68.0           17
# 2            1.1          0.9         630                83.8           43
# 3            1.5          1.4         557                81.9           55
# 4            0.8          0.7         575                76.9           38
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 93 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   xG                          174 non-null    float64
#  1   xGA                         174 non-null    float64
#  2   Poss                        174 non-null    int64
#  3   Formation                   174 non-null    object
#  4   Touches                     174 non-null    int64
#  5   Press                       174 non-null    int64
#  6   Tkl                         174 non-null    int64
#  7   Int                         174 non-null    int64
#  8   Blocks                      174 non-null    int64
#  9   xG_Expected                 174 non-null    float64
#  10  npxG_Expected               174 non-null    float64
#  11  xA_Expected                 174 non-null    float64
#  12  Att_Passes                  174 non-null    int64
# ...

# %%
#value counts for object dtype
df['Formation'].value_counts()
# Out:
# 3-4-3      66
# 4-3-3      62
# 4-2-3-1    17
# 3-5-1-1    12
# 4-1-4-1     7
# 3-5-2       5
# 4-2-2-2     2
# 3-4-1-2     2
# 4-3-2-1     1
# Name: Formation, dtype: int64

# %%
#value counts for object dtype
df['Result'].value_counts()
# Out:
# W    93
# L    41
# D    40
# Name: Result, dtype: int64

# %%
def formation_class(x):
    if x == '3-4-3':
        formation_class = 343
    elif x == '4-3-3':
        formation_class = 433
    elif x == '4-2-3-1':
        formation_class = 4231
    elif x == '3-5-1-1':
        formation_class = 4231
    elif x == '4-1-4-1':
        formation_class = 4141
    elif x == '3-5-2':
        formation_class = 352
    elif x == '4-2-2-2':
        formation_class = 4222
    elif x == '3-4-1-2':
        formation_class = 3412
    elif x == '4-3-2-1':
        formation_class = 4312
        
    return formation_class

# %%
df['formation_class'] = df['Formation'].apply(formation_class)
# Out:
# /var/folders/zb/4sdwymld1s532frv_982h_9m0000gp/T/ipykernel_12043/1840335842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['formation_class'] = df['Formation'].apply(formation_class)

# %%
df['formation_class'].value_counts()
# Out:
# 343     66
# 433     62
# 4231    29
# 4141     7
# 352      5
# 4222     2
# 3412     2
# 4312     1
# Name: formation_class, dtype: int64

# %%
def win_nowin(x):
    if x == 'W':
        win_nowin = 1
    else:
        win_nowin = 0
    return win_nowin

# %%
df['win_nowin'] = df['Result'].apply(win_nowin)
# Out:
# /var/folders/zb/4sdwymld1s532frv_982h_9m0000gp/T/ipykernel_12043/1112339956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['win_nowin'] = df['Result'].apply(win_nowin)

# %%
df['win_nowin'].value_counts()
# Out:
# 1    93
# 0    81
# Name: win_nowin, dtype: int64

# %%
df['win_nowin'].hist(figsize = (5,5))
plt.xlabel('Result', color ='White')
plt.ylabel('Count', color ='White')
plt.title('Win and No-Win Counts (Target Variable)', color ='White')
plt.legend(['0 = No-Win \n 1 = Win '],bbox_to_anchor = (1.05, 0.6))
plt.savefig('target.png')

# %%
df.corrwith(df['win_nowin']).abs().sort_values()
# Out:
# Succ_Dribbles                 0.000354
# Int                           0.001515
# Pass_Blocks                   0.004907
# Att_Vs_Dribbles               0.006594
# CPA_Carries                   0.007424
# Succ_Pressures                0.007867
# FK_Pass_Types                 0.009531
# Att_Medium                    0.011430
# Prog                          0.012040
# Prog_Passes                   0.012040
# Mid.3rd_Tackles               0.013923
# Poss                          0.016005
# Past_Vs_Dribbles              0.018889
# Press_Pressures               0.019554
# Press                         0.019554
# Att.Pen_Touches               0.020324
# Tkl.Int                       0.020888
# Att_Passes                    0.020901
# Tkl_percent_Vs_Dribbles       0.021371
# Att.3rd_Tackles               0.021603
# Touches_Touches               0.023819
# Touches                       0.023819
# Tkl_Tackles                   0.028897
# Tkl                           0.028897
# ...

# %%
sns.lmplot(x="win_nowin", y="Save_percent_Shot_Stopping", data=df)
plt.xlabel('Result')
plt.ylabel('Save Percentage')
plt.title('Save Percentage and Results')
# Out:
# Text(0.5, 1.0, 'Save Percentage and Results')

# %%
sns.lmplot(x="win_nowin", y="SoT", data=df)
plt.xlabel('Result')
plt.ylabel('Shots on Target')
plt.title('Shots on Target and Results')
# Out:
# Text(0.5, 1.0, 'Shots on Target and Results')

# %%
sns.lmplot(x="win_nowin", y="SoTA_Shot_Stopping", data=df)
plt.xlabel('Result')
plt.ylabel('Shots on Target Against')
plt.title('Shots on Target Against and Results')
# Out:
# Text(0.5, 1.0, 'Shots on Target Against and Results')

# %%
sns.lmplot(x="win_nowin", y="Cmp_percent_Passes", data=df)
plt.xlabel('Result')
plt.ylabel('Percentage of passes completed')
plt.title('Percentage of passes completed and Results')
# Out:
# Text(0.5, 1.0, 'Percentage of passes completed and Results')

# %%
df.head()
# Out:
#     xG  xGA  Poss Formation  Touches  Press  Tkl  Int  Blocks  xG_Expected  \
# 0  1.3  0.8    63     3-4-3      668     97   13    9       8          1.3
# 1  0.8  0.6    32   3-5-1-1      449    144   31    5      23          0.8
# 2  1.1  0.6    56     3-4-3      738    146   14    5      10          1.1
# 3  1.5  1.6    58     3-4-3      693    130   26   17      16          1.5
# 4  0.8  1.4    52     3-4-3      700    189   18   16      18          0.8
#
#    npxG_Expected  xA_Expected  Att_Passes  Cmp_percent_Passes  Prog_Passes  \
# 0            1.3          1.1         569                81.9           36
# 1            0.8          0.7         309                68.0           17
# 2            1.1          0.9         630                83.8           43
# 3            1.5          1.4         557                81.9           55
# 4            0.8          0.7         575                76.9           38
#
# ...

# %%
df.drop(['Result', 'Formation'], axis=1, inplace=True)
# Out:
# /Users/z3433848/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 93 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   xG                          174 non-null    float64
#  1   xGA                         174 non-null    float64
#  2   Poss                        174 non-null    int64
#  3   Touches                     174 non-null    int64
#  4   Press                       174 non-null    int64
#  5   Tkl                         174 non-null    int64
#  6   Int                         174 non-null    int64
#  7   Blocks                      174 non-null    int64
#  8   xG_Expected                 174 non-null    float64
#  9   npxG_Expected               174 non-null    float64
#  10  xA_Expected                 174 non-null    float64
#  11  Att_Passes                  174 non-null    int64
#  12  Cmp_percent_Passes          174 non-null    float64
# ...

# %%
#replace nan values with median
df['Save_percent_Shot_Stopping'] = df['Save_percent_Shot_Stopping'].fillna(df['Save_percent_Shot_Stopping'].median())
# Out:
# /var/folders/zb/4sdwymld1s532frv_982h_9m0000gp/T/ipykernel_12043/3053814145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Save_percent_Shot_Stopping'] = df['Save_percent_Shot_Stopping'].fillna(df['Save_percent_Shot_Stopping'].median())

# %%
#replace nan values with median
df['Stp_percent_Crosses'] = df['Stp_percent_Crosses'].fillna(df['Stp_percent_Crosses'].median())
# Out:
# /var/folders/zb/4sdwymld1s532frv_982h_9m0000gp/T/ipykernel_12043/3667724983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Stp_percent_Crosses'] = df['Stp_percent_Crosses'].fillna(df['Stp_percent_Crosses'].median())

# %%
#replace nan values with median
df['AvgDist_Sweeper'] = df['AvgDist_Sweeper'].fillna(df['AvgDist_Sweeper'].median())
# Out:
# /var/folders/zb/4sdwymld1s532frv_982h_9m0000gp/T/ipykernel_12043/3695742776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AvgDist_Sweeper'] = df['AvgDist_Sweeper'].fillna(df['AvgDist_Sweeper'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 93 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   xG                          174 non-null    float64
#  1   xGA                         174 non-null    float64
#  2   Poss                        174 non-null    int64
#  3   Touches                     174 non-null    int64
#  4   Press                       174 non-null    int64
#  5   Tkl                         174 non-null    int64
#  6   Int                         174 non-null    int64
#  7   Blocks                      174 non-null    int64
#  8   xG_Expected                 174 non-null    float64
#  9   npxG_Expected               174 non-null    float64
#  10  xA_Expected                 174 non-null    float64
#  11  Att_Passes                  174 non-null    int64
#  12  Cmp_percent_Passes          174 non-null    float64
# ...

# %%
df.to_csv('df.csv', index=False)
